# %%
import pandas as pd

pin_summary = pd.read_csv("../data/processed/pin_summary.csv")


print(pin_summary.shape)
pin_summary.columns
# Out:
# (96, 18)
# Index(['pincode', 'top10_count', 'top25_count', 'top10_frac', 'top25_frac',
#        'biometric_only_count', 'biometric_only_fraction', 'median_BDR',
#        'mean_BDR', 'high_biometric_only', 'high_BDR', 'mean_CBCR',
#        'median_CBCR', 'low_CBCR', 'mean_ENROL_SAT', 'median_ENROL_SAT',
#        'is_saturated', 'months_total'],
#       dtype='object')

# %%
pin_summary[
    (pin_summary["high_BDR"] == True) |
    (pin_summary["high_biometric_only"] == True)
].shape[0]
# Out:
# 63
